# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/driver_health_with_aqi.csv')

# Features: Health indicators and AQI
X = data[['SPO2', 'Pulse Rate', 'Temperature', 'Sleep Deprivation', 'AQI']]

# Target: Health Status and Air Quality Status
# Health Status logic
data['Health Status'] = ((data['Health Rate'] > 70) & (data['SPO2'] > 94) &
                          (data['Pulse Rate'] <= 100) &
                          (data['Temperature'].between(36, 37.5)) &
                          (data['Sleep Deprivation'] < 3)).astype(int)

# Air Quality Status logic
data['Air Quality Status'] = (data['AQI'] <= 100).astype(int)

# Sleep Deprivation Alert logic
data['Sleep Alert'] = (data['Sleep Deprivation'] > 3).astype(int)

# Update features and targets
X = data[['SPO2', 'Pulse Rate', 'Temperature', 'Sleep Deprivation', 'AQI']]
y_health = data['Health Status']
y_air_quality = data['Air Quality Status']

# %%
# Split data into training and testing sets for both health and air quality
X_train, X_test, y_health_train, y_health_test = train_test_split(X, y_health, test_size=0.2, random_state=42)
_, _, y_air_quality_train, y_air_quality_test = train_test_split(X, y_air_quality, test_size=0.2, random_state=42)

# %%
# Random Forest for Health Prediction
health_model = RandomForestClassifier(n_estimators=100, random_state=42)
health_model.fit(X_train, y_health_train)

# Predict and Evaluate
y_health_pred = health_model.predict(X_test)
health_accuracy = accuracy_score(y_health_test, y_health_pred)
print(f"Health Prediction Accuracy: {health_accuracy}")
print(classification_report(y_health_test, y_health_pred))
# Out:
# Health Prediction Accuracy: 0.94
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       173
#            1       0.78      0.78      0.78        27
#
#     accuracy                           0.94       200
#    macro avg       0.87      0.87      0.87       200
# weighted avg       0.94      0.94      0.94       200

# %%
# Random Forest for Air Quality Prediction
aqi_model = RandomForestClassifier(n_estimators=100, random_state=42)
aqi_model.fit(X_train, y_air_quality_train)

# Predict and Evaluate
y_air_quality_pred = aqi_model.predict(X_test)
air_quality_accuracy = accuracy_score(y_air_quality_test, y_air_quality_pred)
print(f"Air Quality Prediction Accuracy: {air_quality_accuracy}")
print(classification_report(y_air_quality_test, y_air_quality_pred))
# Out:
# Air Quality Prediction Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       130
#            1       1.00      1.00      1.00        70
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200

# %%
# Example for alert checks
for index, row in data.iterrows():
    if row['Sleep Alert'] == 1:
        print(f"Alert: Driver has exceeded sleep deprivation limit (Hours: {row['Sleep Deprivation']})")
    if row['Health Status'] == 0:
        print(f"Alert: Driver is unfit to drive (Health Rate: {row['Health Rate']})")
    if row['Air Quality Status'] == 0:
        print(f"Alert: Poor air quality inside the car (AQI: {row['AQI']})")
# Out:
# Alert: Poor air quality inside the car (AQI: 144.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 287.0)
# Alert: Driver is unfit to drive (Health Rate: 80.0)
# Alert: Poor air quality inside the car (AQI: 163.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Poor air quality inside the car (AQI: 140.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Poor air quality inside the car (AQI: 127.0)
# Alert: Poor air quality inside the car (AQI: 238.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 295.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 186.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 207.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 219.0)
# Alert: Poor air quality inside the car (AQI: 189.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 283.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 236.0)
# Alert: Poor air quality inside the car (AQI: 193.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 286.0)
# Alert: Poor air quality inside the car (AQI: 258.0)
# Alert: Poor air quality inside the car (AQI: 245.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Poor air quality inside the car (AQI: 135.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 279.0)
# Alert: Poor air quality inside the car (AQI: 270.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 170.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 158.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Poor air quality inside the car (AQI: 200.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Poor air quality inside the car (AQI: 263.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Poor air quality inside the car (AQI: 102.0)
# Alert: Poor air quality inside the car (AQI: 124.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 285.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 229.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 145.0)
# Alert: Driver is unfit to drive (Health Rate: 80.0)
# Alert: Poor air quality inside the car (AQI: 196.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 220.0)
# Alert: Driver is unfit to drive (Health Rate: 77.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 170.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 172.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Poor air quality inside the car (AQI: 150.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 121.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 107.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 287.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 105.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 145.0)
# Alert: Poor air quality inside the car (AQI: 270.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 228.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 201.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 211.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 111.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 105.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 138.0)
# Alert: Driver is unfit to drive (Health Rate: 77.0)
# Alert: Poor air quality inside the car (AQI: 298.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Driver is unfit to drive (Health Rate: 93.0)
# Alert: Poor air quality inside the car (AQI: 296.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Poor air quality inside the car (AQI: 213.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 290.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Poor air quality inside the car (AQI: 192.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Poor air quality inside the car (AQI: 149.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 246.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Poor air quality inside the car (AQI: 266.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 250.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Driver is unfit to drive (Health Rate: 80.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Driver is unfit to drive (Health Rate: 77.0)
# Alert: Poor air quality inside the car (AQI: 269.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 224.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 112.0)
# Alert: Driver is unfit to drive (Health Rate: 100.0)
# Alert: Poor air quality inside the car (AQI: 250.0)
# Alert: Poor air quality inside the car (AQI: 232.0)
# Alert: Poor air quality inside the car (AQI: 278.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 201.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 124.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 174.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 255.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 214.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Poor air quality inside the car (AQI: 280.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 236.0)
# Alert: Poor air quality inside the car (AQI: 247.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 205.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 100.0)
# Alert: Poor air quality inside the car (AQI: 126.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 115.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 225.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 265.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 213.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 172.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 208.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Poor air quality inside the car (AQI: 257.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Poor air quality inside the car (AQI: 120.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 297.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 271.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 240.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Poor air quality inside the car (AQI: 242.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 186.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 143.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 261.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Poor air quality inside the car (AQI: 238.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Poor air quality inside the car (AQI: 297.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 187.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Poor air quality inside the car (AQI: 245.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Poor air quality inside the car (AQI: 129.0)
# Alert: Poor air quality inside the car (AQI: 282.0)
# Alert: Driver is unfit to drive (Health Rate: 72.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Poor air quality inside the car (AQI: 262.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 190.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 140.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 253.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 252.0)
# Alert: Poor air quality inside the car (AQI: 291.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Poor air quality inside the car (AQI: 207.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Poor air quality inside the car (AQI: 291.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 283.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 117.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Poor air quality inside the car (AQI: 174.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Poor air quality inside the car (AQI: 150.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 269.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 179.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Poor air quality inside the car (AQI: 123.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 292.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 284.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Poor air quality inside the car (AQI: 194.0)
# Alert: Driver is unfit to drive (Health Rate: 72.0)
# Alert: Poor air quality inside the car (AQI: 227.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 100.0)
# Alert: Poor air quality inside the car (AQI: 274.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 105.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 164.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 284.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 147.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 280.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 163.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Poor air quality inside the car (AQI: 223.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 271.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 145.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 274.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 140.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 220.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Poor air quality inside the car (AQI: 179.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 230.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 115.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 238.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 147.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 287.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 125.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 164.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 277.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 299.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 289.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Poor air quality inside the car (AQI: 297.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 136.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 105.0)
# Alert: Driver is unfit to drive (Health Rate: 93.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 134.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 146.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Poor air quality inside the car (AQI: 158.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 162.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 188.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Poor air quality inside the car (AQI: 180.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 287.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 186.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Poor air quality inside the car (AQI: 137.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 129.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Poor air quality inside the car (AQI: 193.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 272.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 143.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Poor air quality inside the car (AQI: 244.0)
# Alert: Poor air quality inside the car (AQI: 106.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 128.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Poor air quality inside the car (AQI: 208.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 77.0)
# Alert: Poor air quality inside the car (AQI: 224.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 180.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 105.0)
# Alert: Poor air quality inside the car (AQI: 198.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 105.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 279.0)
# Alert: Driver is unfit to drive (Health Rate: 90.0)
# Alert: Poor air quality inside the car (AQI: 259.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Poor air quality inside the car (AQI: 107.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 295.0)
# Alert: Poor air quality inside the car (AQI: 170.0)
# Alert: Poor air quality inside the car (AQI: 194.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 194.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 282.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 181.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 143.0)
# Alert: Poor air quality inside the car (AQI: 181.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Driver is unfit to drive (Health Rate: 100.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 165.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Poor air quality inside the car (AQI: 283.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Poor air quality inside the car (AQI: 280.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 265.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 297.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 295.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 224.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 245.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 207.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Poor air quality inside the car (AQI: 236.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 184.0)
# Alert: Poor air quality inside the car (AQI: 241.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 282.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 161.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 159.0)
# Alert: Driver is unfit to drive (Health Rate: 77.0)
# Alert: Driver is unfit to drive (Health Rate: 77.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Poor air quality inside the car (AQI: 200.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 225.0)
# Alert: Poor air quality inside the car (AQI: 175.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 275.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 80.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Poor air quality inside the car (AQI: 123.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 163.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 158.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Poor air quality inside the car (AQI: 193.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 284.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Poor air quality inside the car (AQI: 155.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Poor air quality inside the car (AQI: 124.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 279.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Poor air quality inside the car (AQI: 109.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Poor air quality inside the car (AQI: 145.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 93.0)
# Alert: Poor air quality inside the car (AQI: 215.0)
# Alert: Driver is unfit to drive (Health Rate: 80.0)
# Alert: Poor air quality inside the car (AQI: 161.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Poor air quality inside the car (AQI: 127.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 149.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 172.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 205.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 126.0)
# Alert: Poor air quality inside the car (AQI: 216.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Poor air quality inside the car (AQI: 163.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Poor air quality inside the car (AQI: 147.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 293.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 194.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 100.0)
# Alert: Poor air quality inside the car (AQI: 150.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 122.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 186.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 148.0)
# Alert: Poor air quality inside the car (AQI: 103.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 242.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 230.0)
# Alert: Driver is unfit to drive (Health Rate: 80.0)
# Alert: Poor air quality inside the car (AQI: 205.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 197.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 141.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 198.0)
# Alert: Driver is unfit to drive (Health Rate: 77.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 287.0)
# Alert: Driver is unfit to drive (Health Rate: 90.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 168.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Poor air quality inside the car (AQI: 260.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 108.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 282.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Poor air quality inside the car (AQI: 103.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 255.0)
# Alert: Poor air quality inside the car (AQI: 205.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 244.0)
# Alert: Poor air quality inside the car (AQI: 286.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 272.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 109.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 189.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 287.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 250.0)
# Alert: Poor air quality inside the car (AQI: 211.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 72.0)
# Alert: Poor air quality inside the car (AQI: 290.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 132.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 200.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Poor air quality inside the car (AQI: 284.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 277.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Poor air quality inside the car (AQI: 218.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 246.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Poor air quality inside the car (AQI: 128.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Poor air quality inside the car (AQI: 211.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Poor air quality inside the car (AQI: 217.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Poor air quality inside the car (AQI: 192.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 110.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 128.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 193.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 111.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 160.0)
# Alert: Poor air quality inside the car (AQI: 130.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 187.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 162.0)
# Alert: Poor air quality inside the car (AQI: 196.0)
# Alert: Poor air quality inside the car (AQI: 203.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Poor air quality inside the car (AQI: 211.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Poor air quality inside the car (AQI: 108.0)
# Alert: Poor air quality inside the car (AQI: 275.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Poor air quality inside the car (AQI: 166.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 259.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 242.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 274.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 101.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 172.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 170.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 140.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 187.0)
# Alert: Driver is unfit to drive (Health Rate: 93.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 110.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 210.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Poor air quality inside the car (AQI: 199.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Poor air quality inside the car (AQI: 297.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 239.0)
# Alert: Poor air quality inside the car (AQI: 114.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 298.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 136.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 210.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Poor air quality inside the car (AQI: 239.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Poor air quality inside the car (AQI: 267.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Poor air quality inside the car (AQI: 206.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 266.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Poor air quality inside the car (AQI: 153.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 293.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 274.0)
# Alert: Poor air quality inside the car (AQI: 229.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Poor air quality inside the car (AQI: 219.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 231.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 262.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 266.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Poor air quality inside the car (AQI: 153.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 139.0)
# Alert: Driver is unfit to drive (Health Rate: 93.0)
# Alert: Poor air quality inside the car (AQI: 116.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Poor air quality inside the car (AQI: 207.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 268.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 117.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Poor air quality inside the car (AQI: 115.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 117.0)
# Alert: Driver is unfit to drive (Health Rate: 75.0)
# Alert: Poor air quality inside the car (AQI: 259.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 121.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Poor air quality inside the car (AQI: 214.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 278.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 234.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 163.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 269.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 285.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 272.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Poor air quality inside the car (AQI: 207.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 237.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 172.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 90.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 109.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 216.0)
# Alert: Poor air quality inside the car (AQI: 105.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 180.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 245.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 243.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 216.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 93.0)
# Alert: Driver is unfit to drive (Health Rate: 100.0)
# Alert: Poor air quality inside the car (AQI: 277.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 209.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 168.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 137.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 229.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 160.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 80.0)
# Alert: Poor air quality inside the car (AQI: 235.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 187.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 131.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 217.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 259.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 177.0)
# Alert: Driver is unfit to drive (Health Rate: 77.0)
# Alert: Poor air quality inside the car (AQI: 188.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Poor air quality inside the car (AQI: 290.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 252.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 291.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 243.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 122.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 298.0)
# Alert: Driver is unfit to drive (Health Rate: 72.0)
# Alert: Poor air quality inside the car (AQI: 282.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 145.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 155.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 100.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Poor air quality inside the car (AQI: 250.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Poor air quality inside the car (AQI: 186.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Poor air quality inside the car (AQI: 259.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 72.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 131.0)
# Alert: Driver is unfit to drive (Health Rate: 100.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Poor air quality inside the car (AQI: 157.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 277.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 202.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# ...
# Alert: Poor air quality inside the car (AQI: 295.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Poor air quality inside the car (AQI: 150.0)
# Alert: Poor air quality inside the car (AQI: 156.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 205.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 178.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 196.0)
# Alert: Poor air quality inside the car (AQI: 222.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Poor air quality inside the car (AQI: 286.0)
# Alert: Driver is unfit to drive (Health Rate: 90.0)
# Alert: Poor air quality inside the car (AQI: 275.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 235.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 182.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 208.0)
# Alert: Driver is unfit to drive (Health Rate: 90.0)
# Alert: Poor air quality inside the car (AQI: 129.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 152.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 121.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 219.0)
# Alert: Driver is unfit to drive (Health Rate: 90.0)
# Alert: Poor air quality inside the car (AQI: 105.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 194.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Poor air quality inside the car (AQI: 185.0)
# Alert: Driver is unfit to drive (Health Rate: 87.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Poor air quality inside the car (AQI: 191.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 213.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Poor air quality inside the car (AQI: 143.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Poor air quality inside the car (AQI: 215.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 216.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 182.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Poor air quality inside the car (AQI: 269.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 143.0)
# Alert: Driver is unfit to drive (Health Rate: 78.0)
# Alert: Poor air quality inside the car (AQI: 110.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Poor air quality inside the car (AQI: 231.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 178.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 209.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 219.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 272.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 190.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 172.0)
# Alert: Driver is unfit to drive (Health Rate: 72.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Poor air quality inside the car (AQI: 154.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 214.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Poor air quality inside the car (AQI: 133.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 284.0)
# Alert: Driver is unfit to drive (Health Rate: 72.0)
# Alert: Poor air quality inside the car (AQI: 125.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 173.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 151.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 114.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 283.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Poor air quality inside the car (AQI: 165.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 188.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Driver is unfit to drive (Health Rate: 83.0)
# Alert: Poor air quality inside the car (AQI: 175.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Poor air quality inside the car (AQI: 183.0)
# Alert: Poor air quality inside the car (AQI: 221.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 178.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Poor air quality inside the car (AQI: 275.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 111.0)
# Alert: Driver is unfit to drive (Health Rate: 68.0)
# Alert: Poor air quality inside the car (AQI: 223.0)
# Alert: Poor air quality inside the car (AQI: 213.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 108.0)
# Alert: Poor air quality inside the car (AQI: 156.0)
# Alert: Driver is unfit to drive (Health Rate: 60.0)
# Alert: Poor air quality inside the car (AQI: 190.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 199.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Poor air quality inside the car (AQI: 195.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 245.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 236.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 100.0)
# Alert: Poor air quality inside the car (AQI: 103.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Poor air quality inside the car (AQI: 282.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 94.0)
# Alert: Poor air quality inside the car (AQI: 218.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 80.0)
# Alert: Poor air quality inside the car (AQI: 229.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Poor air quality inside the car (AQI: 171.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 122.0)
# Alert: Poor air quality inside the car (AQI: 297.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 177.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 164.0)
# Alert: Driver is unfit to drive (Health Rate: 77.0)
# Alert: Poor air quality inside the car (AQI: 186.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 208.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 226.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 223.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 91.0)
# Alert: Poor air quality inside the car (AQI: 174.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 115.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 269.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Poor air quality inside the car (AQI: 252.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 84.0)
# Alert: Poor air quality inside the car (AQI: 272.0)
# Alert: Driver is unfit to drive (Health Rate: 76.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 115.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 150.0)
# Alert: Driver is unfit to drive (Health Rate: 73.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 205.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 270.0)
# Alert: Driver is unfit to drive (Health Rate: 62.0)
# Alert: Driver is unfit to drive (Health Rate: 66.0)
# Alert: Poor air quality inside the car (AQI: 291.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 246.0)
# Alert: Poor air quality inside the car (AQI: 263.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 189.0)
# Alert: Driver is unfit to drive (Health Rate: 89.0)
# Alert: Driver is unfit to drive (Health Rate: 98.0)
# Alert: Poor air quality inside the car (AQI: 188.0)
# Alert: Poor air quality inside the car (AQI: 255.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Poor air quality inside the car (AQI: 221.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 240.0)
# Alert: Poor air quality inside the car (AQI: 268.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Driver is unfit to drive (Health Rate: 96.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 235.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 81.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 191.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Poor air quality inside the car (AQI: 252.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 92.0)
# Alert: Poor air quality inside the car (AQI: 208.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 74.0)
# Alert: Poor air quality inside the car (AQI: 244.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Poor air quality inside the car (AQI: 290.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Poor air quality inside the car (AQI: 271.0)
# Alert: Driver is unfit to drive (Health Rate: 88.0)
# Alert: Poor air quality inside the car (AQI: 121.0)
# Alert: Driver is unfit to drive (Health Rate: 63.0)
# Alert: Poor air quality inside the car (AQI: 127.0)
# Alert: Driver is unfit to drive (Health Rate: 71.0)
# Alert: Poor air quality inside the car (AQI: 112.0)
# Alert: Driver is unfit to drive (Health Rate: 61.0)
# Alert: Poor air quality inside the car (AQI: 272.0)
# Alert: Poor air quality inside the car (AQI: 129.0)
# Alert: Driver has exceeded sleep deprivation limit (Hours: 4.0)
# Alert: Driver is unfit to drive (Health Rate: 90.0)
# Alert: Poor air quality inside the car (AQI: 131.0)
# Alert: Driver is unfit to drive (Health Rate: 95.0)
# Alert: Driver is unfit to drive (Health Rate: 85.0)
# Alert: Driver is unfit to drive (Health Rate: 86.0)
# Alert: Poor air quality inside the car (AQI: 147.0)
# Alert: Driver is unfit to drive (Health Rate: 64.0)
# Alert: Driver is unfit to drive (Health Rate: 79.0)
# Alert: Poor air quality inside the car (AQI: 104.0)
# Alert: Driver is unfit to drive (Health Rate: 70.0)
# Alert: Poor air quality inside the car (AQI: 164.0)
# Alert: Driver is unfit to drive (Health Rate: 69.0)
# Alert: Poor air quality inside the car (AQI: 200.0)
# Alert: Driver is unfit to drive (Health Rate: 99.0)
# Alert: Poor air quality inside the car (AQI: 196.0)
# Alert: Driver is unfit to drive (Health Rate: 97.0)
# Alert: Poor air quality inside the car (AQI: 184.0)
# Alert: Driver is unfit to drive (Health Rate: 65.0)
# Alert: Poor air quality inside the car (AQI: 264.0)
# Alert: Driver is unfit to drive (Health Rate: 67.0)
# Alert: Driver is unfit to drive (Health Rate: 82.0)
# Alert: Poor air quality inside the car (AQI: 213.0)

# %%
data
# Out:
#      Health Rate  SPO2  Pulse Rate  Temperature  Sleep Deprivation  AQI  \
# 0             98    99          82    36.044070                  0  144
# 1             88   100         102    37.440016                  0   49
# 2             74    99         114    36.835980                  1   64
# 3             67    97          75    36.177680                  4  287
# 4             80    91         106    37.367508                  1  163
# ..           ...   ...         ...          ...                ...  ...
# 995           99    95          80    37.570538                  3  196
# 996           97    91          71    37.202205                  3  184
# 997           65   100         116    37.980724                  2  264
# 998           67   100         120    36.650508                  1   99
# 999           82    94         100    37.882545                  3  213
#
#      Health Status  Air Quality Status  Sleep Alert
# 0                1                   0            0
# 1                0                   1            0
# 2                0                   1            0
# 3                0                   0            1
# 4                0                   0            0
# ..             ...                 ...          ...
# 995              0                   0            0
# 996              0                   0            0
# 997              0                   0            0
# 998              0                   1            0
# 999              0                   0            0
#
# [1000 rows x 9 columns]

# %%
import joblib
joblib.dump(health_model, 'health_model.pkl')
joblib.dump(aqi_model, 'aqi_model.pkl')
# Out:
# ['aqi_model.pkl']
